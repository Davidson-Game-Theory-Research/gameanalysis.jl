# %%
using DelimitedFiles
using Plots

# %%
RW_CPU = readdlm("RepWeightCPU_bounds.csv", ',', Int);
RW_CPU[6,1:150] .= 1
RW_GPU = readdlm("RepWeightGPU_bounds.csv", ',', Int);

# %%
heatmap(1:500, 1:6, RW_GPU, c=cgrad([:black, :red, :green]),
        xlabel="players", ylabel="actions", title="RepWeight_GPU: threshold = 1e-5")

# %%
heatmap(1:500, 1:6, RW_CPU, c=cgrad([:black, :red, :green]),
        xlabel="players", ylabel="actions", title="RepWeight_CPU: threshold = 1e-8")
